# %% [markdown]
# <a href="https://colab.research.google.com/github/narenmentor/Competitions/blob/main/DS_Crash_course_Youtube_Contest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Group 64908.png](data:image/png;base64,...)

# %% [markdown]
# # Data Science Crash Course Youtube Contest
#
# Instructions:
#
# Hello Guys, Welcome to Data Science Crash Course Contest!
#
# Nenga Successful ah Data Science Crash Course complete pannirupinga incase nenga miss pannirundha links kodukren first la irundhu learn pannitu vanga!
#
# Playlist link: https://www.youtube.com/playlist?list=PLbN6X9QXZq0d-jmjUerjtRJsHT9LX0a09
#
#
# - Once above videos complete fulla watch pannitingana indha mini test la participate pannunga.
# - Indha Contest epdi attend pannanmnu oru video iruku watch that also!
#
#
# ## What to do?
#
# - Go to file --> Save a Copy in Drive --> Then andha file la nenga work pannalam.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Question irukum adhuku keela code cell la unga answer ah type pannunga! Reference videos oda linkum ovvoru section la update panniruken so easy ya refer panninkonga!
#
# - Once ella questions kum answer pannita unga colab link ah share pannanum.
#
# - Top Right corner la Share option click pannitu, Anyone with the link click pannitu link copy paniklam.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Submission
#
# - Then indha video keela iruka google forms la unga name, phone number, email id, city, Student/Working/Job Seeker and the Content Colab link idhelam share pannitu submit pannirunga!

# %% [markdown]
# # Python Questions
#
# Reference Video - https://youtu.be/75ba8h1dDKM?si=VtDJyamJjzANlgqF

# %% [markdown]
# 1. Write a Python program that asks the user for their name and age, and then prints a message like:
#
# “Hello John! You are 20 years old.”
#
#
# Example Output:
#
#
# Enter your name: John
# Enter your age: 20
# Hello John! You are 20 years old.
#
# Hint: Use input() function to get the input

# %%
# Example
username = input("Enter your Name:")
# Out:
# Enter your Name:Entri

# %% [markdown]
# 2. Write a program to check whether a number entered by the user is even or odd.
#
# Example Output:
#
# Enter a number: 7
# 7 is an odd number.

# %% [markdown]
# 3. Write a program to print numbers from 1 to 10 using a for loop.

# %% [markdown]
# 4. Create a list of 5 fruits and print the first and last fruit from the list.
#
# Example Output:
#
# Fruits list: ['apple', 'banana', 'mango', 'grapes', 'orange']
# First fruit: apple
# Last fruit: orange

# %% [markdown]
# 5. Write a Python function square(num) that returns the square of a number.
# Then, call the function for the number 5.
#
# Example Output:
#
# 25

# %% [markdown]
# # Exploratory Data Analysis using Pandas
#
# Reference video 1 - https://youtu.be/vW-jzvJjAp8?si=Dmas2X28JZR6ZP6_
#
# Refernce video 2 -  https://youtu.be/8V0KXZUBxHc?si=r6mve6n1ZcAM9djs
#
# Refernce video 3 - https://youtu.be/8MJg1hJE06c?si=e8wq2FR-VmTOB3y0

# %% [markdown]
# 6. Create a Pandas DataFrame using a Python dictionary that contains the following data:
#
# | Name  | Age | City     |
# | ----- | --- | -------- |
# | John  | 25  | New York |
# | Emma  | 30  | London   |
# | Rahul | 22  | Mumbai   |

# %% [markdown]
# 7. Read the CSV data from the below link and display the first and last 5 rows
#
# dataset link - https://raw.githubusercontent.com/narenmentor/Datasets/refs/heads/main/Zomato-data-.csv

# %% [markdown]
# 8. Given a DataFrame df with a numeric column ‘Sales’,
# find the mean, maximum, and minimum sales values.

# %% [markdown]
# # Data Visualization using Matplotlib
#
# Reference link 1 - https://youtu.be/QMaGXgYQ-Lw?si=6LalH74lckzafKP6
#
# Refernce video 2 -https://youtu.be/8MJg1hJE06c?si=e8wq2FR-VmTOB3y0

# %% [markdown]
# 9. Plot a simple line graph for the following data using Matplotlib:
#
# x = [1, 2, 3, 4, 5]
#
# y = [2, 4, 6, 8, 10]

# %% [markdown]
# 10. Using the same data as above, add the following details to your line plot:
#
# Title: "Simple Line Plot"
#
# X-axis label: "X Values"
#
# Y-axis label: "Y Values"

# %% [markdown]
# 11. Create a bar chart to show the sales of different products.
#
#
# | Product | Sales |
# | ------- | ----- |
# | A       | 50    |
# | B       | 70    |
# | C       | 30    |
# | D       | 90    |

# %% [markdown]
# 12. Create a pie chart showing the percentage distribution of expenses:
#
# | Category | Expense |
# | -------- | ------- |
# | Rent     | 40      |
# | Food     | 25      |
# | Travel   | 20      |
# | Others   | 15      |

# %% [markdown]
# 13. Plot a scatter plot for the following data showing height vs weight:
#
# height = [150, 160, 170, 180, 190]
#
# weight = [50, 60, 65, 70, 80]

# %% [markdown]
# # Machine Learning Model
#
# Reference Video 1 - https://youtu.be/stlqt34cAoY?si=EAt_Q0dDfOCMLlOU
#
# Reference Video 2 - https://youtu.be/obwaZ6fUf5c?si=50ZHlUqYn-QyIk9o

# %% [markdown]
# 14. Predict Student Scores Based on Study Hours
#
# Scenario:
# A teacher wants to understand how the number of hours a student studies affects their exam score. You are given a simple dataset showing study hours and corresponding scores.
#
# | Hours | Score |
# | ----- | ----- |
# | 1.5   | 20    |
# | 3.0   | 35    |
# | 4.5   | 50    |
# | 5.0   | 55    |
# | 6.0   | 65    |
# | 7.0   | 70    |
# | 8.0   | 80    |
#
#
# Task:
#
# Create a Simple Linear Regression model using this data.
#
# Plot the regression line showing the relationship between study hours and scores.
#
# Predict the score of a student who studies 6.5 hours.

# %% [markdown]
# # Submit this file in the below google forms
#
# FORM LINK - https://forms.gle/n5Q2DUYPLjYCf6bRA
